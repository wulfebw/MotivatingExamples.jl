# %%
using JLD
using MotivatingExamples
using PGFPlots

# %%
# store results for all runs in a nested dictionary
# top-level key = experiment name 
# middle-level key = run iteration
# bottom-level key = information of interest
results = Dict();

# %%
function update_results(r::Dict, trainer::Trainer, learner::Learner, env::Env, policy::Policy, 
        topkey::String, midkey::Int, adaptive::Bool, n_steps::Int)
    m = trainer.monitor
    
    # add the topkey if not already added
    if !in(topkey, keys(r))
        r[topkey] = Dict()
        r[topkey]["adaptive"] = adaptive
        r[topkey]["n_steps"] = n_steps
    end
    r[topkey][midkey] = Dict()
    r[topkey][midkey]["learning_curve"] = m.info["state-value rmse loss"][:]
    state_values = predict(learner, m.eval_states)
    r[topkey][midkey]["state_values"] = state_values
    r[topkey][midkey]["final_loss"] = rmse(m.v_true, state_values)
end

function aggregate_results_across_runs(r::Dict)
    aggregate_results = Dict()
    for (experiment_name, runs) in r
        mean_final_loss = 0
        state_values = zeros(size(runs[1]["state_values"]))
        
        min_learning_curve_length = typemax(Int)
        for (run, _) in runs
            if typeof(run) == Int
                min_learning_curve_length = min(length(runs[run]["learning_curve"]), min_learning_curve_length)
            end
        end
        learning_curve = zeros(min_learning_curve_length)
        run_count = 0
        for (run, run_results) in runs
            if typeof(run) == Int
                run_count += 1
                mean_final_loss += run_results["final_loss"]
                state_values .+= run_results["state_values"]
                learning_curve .+= run_results["learning_curve"][1:min_learning_curve_length]
            end
        end
        aggregate_results[experiment_name] = Dict()
        aggregate_results[experiment_name]["final_loss"] = mean_final_loss ./ run_count
        aggregate_results[experiment_name]["state_values"] = state_values ./ run_count
        aggregate_results[experiment_name]["learning_curve"] = learning_curve ./ run_count
        aggregate_results[experiment_name]["adaptive"] = runs["adaptive"]
        aggregate_results[experiment_name]["n_steps"] = runs["n_steps"]
    end
    return aggregate_results
end
# Out:
# aggregate_results_across_runs (generic function with 1 method)

# %%
# 1D, shared settings, objects

# env 
env = Continuous2DRareEventEnv()

# policy
policy = MultivariateGaussianPolicy()

# learner settings
nbins = 40 # number of bins at which to linearly interpolate
bins = linspace(env.xmin, env.xmax, nbins)
grid = RectangleGrid(bins, bins)
target_dim = 1 # output dim of learner
lr = .1
discount = 1.

# evaluation
n_runs = 5
n_eval_bins = 50
eval_states_x = linspace(env.xmin, env.xmax, n_eval_bins)
eval_states_y = linspace(env.ymin, env.ymax, n_eval_bins)
eval_states = zeros(2, n_eval_bins, n_eval_bins)
for i in 1:n_eval_bins
    for j in 1:n_eval_bins
    eval_states[1,i,j] = eval_states_x[i]
    eval_states[2,i,j] = eval_states_y[j]
    end
end
eval_states = reshape(eval_states, 2, n_eval_bins * n_eval_bins)
v_true = ones(n_eval_bins)

# training settings 
run_eval_every = 5000 # how frequently to check performance
budget = typemax(Float64) # training is based on steps not real time
max_step_count = 100000
update_dist_freq = 5000 # only applies if actually adaptive
util_temp = 1. # softmax temp for utilities only applies if actually adaptive
timer = BudgetTimer(budget) # will be reset each run
monitor = TrainingMonitor(timer = timer, eval_states = eval_states, # will also be reset for each training call
        v_true = v_true, run_eval_every = run_eval_every);

# %%
# get true values if necessary
if discount != 1.
    learner = MCLearner(grid, target_dim, discount = discount, lr = lr)
    true_trainer_step_count = max_step_count * 10
    trainer = AdaptiveTrainer(
                nothing,
                monitor,
                max_episode_steps = 5, # n-step MC / TD
                num_mc_runs = 1,
                max_step_count = true_trainer_step_count,
                update_dist_freq = -1,
                util_temp = util_temp
        )
    reinitialize(learner)
    reinitialize(trainer)
    train(trainer, learner, env, policy)
    v_true = predict(learner, collect(eval_states))
    monitor.v_true = v_true
end

# %%
# 2D, TD(0)
for adaptive in [false, true]
    learner = TDLearner(grid, target_dim, discount = discount, lr = lr)
    trainer = AdaptiveTrainer(
            nothing,
            monitor,
            max_episode_steps = 1,
            num_mc_runs = 1,
            max_step_count = max_step_count,
            update_dist_freq = adaptive ? update_dist_freq : -1,
            util_temp = util_temp
    )
    exp_name = adaptive ? "TD(0) Adaptive" : "TD(0)"
    for run in 1:n_runs
        reinitialize(learner)
        reinitialize(trainer)
        train(trainer, learner, env, policy)
        update_results(results, trainer, learner, env, policy, exp_name, run, adaptive, 1)
    end
end

# %%
# 2D, N-step MC / TD
for adaptive in [false, true]
    for n_steps in [50, 500]
        learner = MCLearner(grid, target_dim, discount = discount, lr = lr)
        trainer = AdaptiveTrainer(
                nothing,
                monitor,
                max_episode_steps = n_steps, # n-step MC / TD
                num_mc_runs = 1,
                max_step_count = max_step_count,
                update_dist_freq = adaptive ? update_dist_freq : -1,
                util_temp = util_temp
        )
        exp_name = adaptive ? "$(n_steps)-Step TD Adaptive" : "$(n_steps)-Step TD"
        for run in 1:n_runs
            reinitialize(learner)
            reinitialize(trainer)
            train(trainer, learner, env, policy)
            update_results(results, trainer, learner, env, policy, exp_name, run, adaptive, n_steps)
        end
    end
end
# Out:
# exception raised while getting the gmm dists: ArgumentError("matrix is not symmetric/Hermitian. This error can be avoided by calling cholfact(Hermitian(A)) which will ignore either the upper or lower triangle of the matrix.")
# component 1
# μ: [NaN,NaN]
# Σ: [NaN NaN; NaN NaN]
# component 2
# μ: [NaN,NaN]
# Σ: [NaN NaN; NaN NaN]
# ArgumentError: matrix is not symmetric/Hermitian. This error can be avoided by calling cholfact(Hermitian(A)) which will ignore either the upper or lower triangle of the matrix.
#
#  in incorporate_feedback(::MotivatingExamples.AdaptiveTrainer, ::Dict{String,Array{Float64,N}}, ::MotivatingExamples.Continuous2DRareEventEnv, ::MotivatingExamples.MultivariateGaussianPolicy) at /Users/wulfebw/Dropbox/School/Stanford/research/risk/MotivatingExamples.jl/src/trainer.jl:156
#  in run_training_step at /Users/wulfebw/Dropbox/School/Stanford/research/risk/MotivatingExamples.jl/src/trainer.jl:63 [inlined]
#  in train(::MotivatingExamples.AdaptiveTrainer, ::MotivatingExamples.MCLearner, ::MotivatingExamples.Continuous2DRareEventEnv, ::MotivatingExamples.MultivariateGaussianPolicy) at /Users/wulfebw/Dropbox/School/Stanford/research/risk/MotivatingExamples.jl/src/trainer.jl:69
#  in macro expansion; at ./In[7]:18 [inlined]
#  in anonymous at ./<missing>:?

# %%
# aggregate results
agg_results = aggregate_results_across_runs(results);

# %%
# save results
JLD.save("../data/run_results_2D.jld", "results", results);
JLD.save("../data/agg_results_2D.jld", "agg_results", agg_results);

# %%
# visualize learning curves
# g = GroupPlot(t_max_nbins, mc_nbins, groupStyle = "horizontal sep = 1.5cm, vertical sep = 1.4cm")
a = Axis(legendPos="south west", width="20cm", height="12cm", xlabel="Environment Steps", ylabel="Root Mean Square Error", 
title="Error in Estimated Risk")
markcolors = Dict(1=>"red", 50=>"blue", 500=>"green")
for (i, (exp_name, exp_results)) in enumerate(agg_results)
    curve = exp_results["learning_curve"]
    timesteps = linspace(0, max_step_count, length(curve))
    marker = exp_results["adaptive"] ? "diamond" : "o"
    markcolor = markcolors[exp_results["n_steps"]]
    marker = contains(exp_name, "Adaptive") ? "diamond" : "o"
    p = Plots.Linear(timesteps, curve, 
        legendentry="$(exp_name)",
        mark=marker,
        style="$(markcolor),thick",
        markSize=4)
    push!(a, p)
end
PGFPlots.save("../data/results/motivating_learning_curve_2D.pdf", a)
a
# Out:
# PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[0.0 5263.16 … 94736.8 100000.0; 1.0 1.0 … 0.999743 0.999744],"diamond",4,"red,thick","TD(0) Adaptive",nothing,nothing),PGFPlots.Plots.Linear(Real[0.0 5555.56 … 94444.4 100000.0; 1.0 1.0 … 0.949994 0.942243],"o",4,"green,thick","500-Step TD",nothing,nothing),PGFPlots.Plots.Linear(Real[0.0 5263.16 … 94736.8 100000.0; 0.99996 0.999937 … 0.999677 0.999667],"o",4,"red,thick","TD(0)",nothing,nothing),PGFPlots.Plots.Linear(Real[0.0 5555.56 … 94444.4 100000.0; 0.999905 0.998449 … 0.994466 0.994431],"o",4,"blue,thick","50-Step TD",nothing,nothing),PGFPlots.Plots.Linear(Real[0.0 5555.56 … 94444.4 100000.0; 1.0 1.0 … 0.992675 0.992539],"diamond",4,"blue,thick","50-Step TD Adaptive",nothing,nothing),PGFPlots.Plots.Linear(Real[0.0 5555.56 … 94444.4 100000.0; 1.0 1.0 … 0.954078 0.955569],"diamond",4,"green,thick","500-Step TD Adaptive",nothing,nothing)],"Error in Estimated Risk","Environment Steps",nothing,"Root Mean Square Error",nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"20cm","12cm",nothing,"south west",nothing,nothing,nothing,nothing,nothing,nothing,"axis")

# %%
# plot all the value functions
g = GroupPlot(3, 3, groupStyle = "horizontal sep = 2cm, vertical sep = 2cm")
markcolors = ["red", "blue", "green", "black"]
for (i, (exp_name, exp_results)) in enumerate(agg_results)
    
    state_values = reshape(exp_results["state_values"], n_eval_bins, n_eval_bins)
    function get_heat(x, y)
        xind = Int(floor(x - env.xmin + 1))
        yind = Int(floor(y - env.ymin + 1))
        return state_values[xind, yind]
    end
    final_loss = round(exp_results["final_loss"], 4)
    nbins = 20
    img = Axis(Plots.Image(get_heat, (env.xmin, env.xmax), (env.ymin, env.ymax), xbins=nbins, ybins=nbins), 
        title="$(exp_name)")
    push!(g, img)
end
PGFPlots.save("../data/results/motivating_state_values_2D.pdf", g)
g
# Out:
# PGFPlots.GroupPlot(PGFPlots.Axis[PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Image("tmp_10000000000001.png",-10.0,10.0,-10.0,10.0,1.30461e-5,0.00572903,true,PGFPlots.ColorMaps.GrayMap(false),nothing)],"TD(0) Adaptive",nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis"),PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Image("tmp_10000000000002.png",-10.0,10.0,-10.0,10.0,0.0401156,0.0807697,true,PGFPlots.ColorMaps.GrayMap(false),nothing)],"500-Step TD",nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis"),PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Image("tmp_10000000000003.png",-10.0,10.0,-10.0,10.0,5.98885e-6,0.00886731,true,PGFPlots.ColorMaps.GrayMap(false),nothing)],"TD(0)",nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis"),PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Image("tmp_10000000000004.png",-10.0,10.0,-10.0,10.0,0.0051873,0.0271693,true,PGFPlots.ColorMaps.GrayMap(false),nothing)],"50-Step TD",nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis"),PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Image("tmp_10000000000005.png",-10.0,10.0,-10.0,10.0,0.00891548,0.0254346,true,PGFPlots.ColorMaps.GrayMap(false),nothing)],"50-Step TD Adaptive",nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis"),PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Image("tmp_10000000000006.png",-10.0,10.0,-10.0,10.0,0.0315803,0.102213,true,PGFPlots.ColorMaps.GrayMap(false),nothing)],"500-Step TD Adaptive",nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis")],(3,3),nothing,"horizontal sep = 2cm, vertical sep = 2cm")
